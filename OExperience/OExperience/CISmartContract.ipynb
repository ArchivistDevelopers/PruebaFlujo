# %%
import re
import subprocess

class Git:
    def git
class CISmartContract:
    def test(self):
        if self.TruffleTest():return 'Hay errores en los tests de Truffle'
        elif self.PythonTest():return self.errores

        return True

    def TruffleTest(self):
        self.testTruffle = subprocess.run('truffle test',capture_output=True, shell=True, text=True)
        proc = subprocess.Popen('truffle test', stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
        fail = []
        while True:
            line = proc.stdout.readline()
            if not line:
                break
            print(line.decode("utf-8"))

            if re.search('failing', line.decode("utf-8")):
                fail.append(line)

        if fail: return True
        return False

    def PythonTest(self):
        subprocess.run('conda activate CISmartContracts & slither . --checklist > analysis.md', shell=True)
        with open('analysis.md','r') as file:
            test = file.readlines()
        self.errores = [line for line in test if re.search("^\#{2}", line)]
        if self.errores: return True
        return False

def testing():
    testingFlow = CISmartContract()
    print(testingFlow.test())

def foo():
    print('hola')
# Out:
# Hay errores en Truffle

# %%
import sys
print(sys.platform)
# Out:
# win32

# %%
import subprocess
ts = subprocess.run('truffle test',capture_output=True, shell=True, text=True)

# %%
import subprocess
proc = subprocess.Popen('truffle test', stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)
while True:
    line = proc.stdout.readline()
    if not line:
        break
    print(line.decode("utf-8"))
# Out:
# Using network 'development'.
#
#
#
#
#
# Compiling your contracts...
#
# ...
#
# > Compiling @chainlink\contracts\src\v0.8\interfaces\AggregatorV3Interface.sol
#
# > Compiling .\contracts\ArtCollectibles.sol
#
# > Compiling .\contracts\ClubOptions.sol
#
# > Compiling .\contracts\Genesis.sol
#
# > Compiling .\contracts\MainExp.sol
#
# > Compiling .\contracts\Migrations.sol
#
# > Compiling .\contracts\OEToken.sol
#
# > Compiling .\contracts\Services.sol
#
# > Compiling .\contracts\Treasury.sol
#
# > Compiling .\contracts\interfaces\IGenesis.sol
#
# > Compiling .\contracts\interfaces\IOEToken.sol
#
# > Compiling .\contracts\interfaces\standard\IERC165.sol
#
# > Compiling .\contracts\interfaces\standard\IERC20.sol
#
# > Compiling .\contracts\interfaces\standard\IERC2981.sol
#
# > Compiling .\contracts\interfaces\standard\IERC721.sol
#
# > Compiling .\contracts\interfaces\standard\IERC721Enumerable.sol
#
# > Compiling .\contracts\interfaces\standard\IERC721Metadata.sol
#
# ...

# %%
pip install chardet
# Out:
# ...
#      -------------------------------------- 199.1/199.1 kB 5.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script chardetect.exe is installed in 'c:\Users\coque\anaconda3\envs\CISmartContracts\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import chardet
chardet.detect(←[0m←[0m)
# Out:
#   Cell In[7], line 2
#     chardet.detect(←←)
#                    ^
# SyntaxError: invalid character '←' (U+2190)

# %%
if ts.stderr:
    print(True)
# Out:
# True

# %%
def log_callback(log, status, process_result):
  print(log)
p1 = subprocess.run('bash -c "activate CISmartContracts; slither . --checklist > analysis.md"', stdout=subprocess.PIPE, stderr=subprocess.PIPE, shell=True)

# %%
commands = ["conda activate CISmartContracts", " slither . --checklist > analysis.md"]
for command in commands:
    subprocess.call(command, shell=True)

# %%
subprocess.run('conda activate CISmartContracts | slither .',shell=True, capture_output=True)
# p2 = subprocess.Popen('slither .', shell=True)
# Out:
# CompletedProcess(args='conda activate CISmartContracts | slither .', returncode=255, stdout=b'', stderr=b'"slither" no se reconoce como un comando interno o externo,\r\nprograma o archivo por lotes ejecutable.\r\n')

# %%
subprocess.run('truffle test',capture_output=True, shell=True, text=True)
# Out:
# CompletedProcess(args='truffle test', returncode=0, stdout="Using network 'development'.\n\n\nCompiling your contracts...\n===========================\n> Compiling @chainlink\\contracts\\src\\v0.8\\interfaces\\AggregatorV3Interface.sol\n> Compiling .\\contracts\\ArtCollectibles.sol\n> Compiling .\\contracts\\ClubOptions.sol\n> Compiling .\\contracts\\Genesis.sol\n> Compiling .\\contracts\\MainExp.sol\n> Compiling .\\contracts\\Migrations.sol\n> Compiling .\\contracts\\OEToken.sol\n> Compiling .\\contracts\\Services.sol\n> Compiling .\\contracts\\Treasury.sol\n> Compiling .\\contracts\\interfaces\\IGenesis.sol\n> Compiling .\\contracts\\interfaces\\IOEToken.sol\n> Compiling .\\contracts\\interfaces\\standard\\IERC165.sol\n> Compiling .\\contracts\\interfaces\\standard\\IERC20.sol\n> Compiling .\\contracts\\interfaces\\standard\\IERC2981.sol\n> Compiling .\\contracts\\interfaces\\standard\\IERC721.sol\n> Compiling .\\contracts\\interfaces\\standard\\IERC721Enumerable.sol\n> Compiling .
# ...

# %%
import subprocess

subprocess.run('conda activate CISmartContracts & slither . --checklist > analysis.md', shell=True)
# Out:
# CompletedProcess(args=' conda activate CISmartContracts & slither . --checklist > analysis.md', returncode=4294967295, stdout='', stderr="'truffle.cmd compile --all' running (use --truffle-version truffle@x.x.x to use specific version)\n\n\nCompiling your contracts...\n===========================\n> Compiling @chainlink\\contracts\\src\\v0.8\\interfaces\\AggregatorV3Interface.sol\n> Compiling .\\contracts\\ArtCollectibles.sol\n> Compiling .\\contracts\\ClubOptions.sol\n> Compiling .\\contracts\\Genesis.sol\n> Compiling .\\contracts\\MainExp.sol\n> Compiling .\\contracts\\Migrations.sol\n> Compiling .\\contracts\\OEToken.sol\n> Compiling .\\contracts\\Services.sol\n> Compiling .\\contracts\\Treasury.sol\n> Compiling .\\contracts\\interfaces\\IGenesis.sol\n> Compiling .\\contracts\\interfaces\\IOEToken.sol\n> Compiling .\\contracts\\interfaces\\standard\\IERC165.sol\n> Compiling .\\contracts\\interfaces\\standard\\IERC20.sol\n> Compiling .\\contracts\\interfaces\\standard\\IERC2981.sol
# ...

# %%
subprocess.run("conda activate CISmartContracts; cd ~/Documents/GitHubPrueba/OExperience/OExperience", capture_output=True, text=True, shell=True)
# Out:
# CompletedProcess(args="conda activate 'CISmartContracts'; cd ~/Documents/GitHubPrueba/OExperience/OExperience", returncode=2, stdout='', stderr='activate does not accept more than one argument:\n["\'CISmartContracts\';", \'cd\', \'~/Documents/GitHubPrueba/OExperience/OExperience\']\n\n')

# %%
my_env
# Out:
# {'ALLUSERSPROFILE': 'C:\\ProgramData',
#  'APPDATA': 'C:\\Users\\coque\\AppData\\Roaming',
#  'BASE_URI': 'https//oexperience.io/metadata/',
#  'CHROME_CRASHPAD_PIPE_NAME': '\\\\.\\pipe\\LOCAL\\crashpad_14528_BLPTJNPJUOVBLSOV',
#  'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#  'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#  'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#  'COMPUTERNAME': 'LAPTOP-U0J1VIR0',
#  'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#  'CONDA_BAT': 'C:\\Users\\coque\\anaconda3\\condabin\\conda.bat',
#  'CONDA_EXE': 'C:\\Users\\coque\\anaconda3\\Scripts\\conda.exe',
#  'CONDA_SHLVL': '0',
#  'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#  'ELECTRON_NO_ATTACH_CONSOLE': '1',
#  'ELECTRON_RUN_AS_NODE': '1',
#  'HOMEDRIVE': 'C:',
#  'HOMEPATH': '\\Users\\coque',
#  'JPY_INTERRUPT_EVENT': '2084',
#  'LOCALAPPDATA': 'C:\\Users\\coque\\AppData\\Local',
#  'LOGONSERVER': '\\\\LAPTOP-U0J1VIR0',
# ...

# %%
import subprocess, os
# my_env = os.environ.copy()
# my_env["PATH"] = "/usr/sbin:/sbin:" + my_env['PATH'].split(';')[0]
my_command = 'slither . --checklist > analysis.md'

subprocess.run(my_command, shell=True, capture_output=True ,env={'PATH':"/usr/sbin:/sbin:c:/Users/coque/anaconda3/envs/CISmartContracts"} )
# Out:
# CompletedProcess(args='slither . --checklist > analysis.md', returncode=1, stdout=b'', stderr=b'"DOSKEY" no se reconoce como un comando interno o externo,\r\nprograma o archivo por lotes ejecutable.\r\n"slither" no se reconoce como un comando interno o externo,\r\nprograma o archivo por lotes ejecutable.\r\n')

# %%
my_env = os.environ.copy()

# %%
my_env['PATH'].split(';')[0]
# Out:
# 'c:\\Users\\coque\\anaconda3\\envs\\CISmartContracts;C:\\Users\\coque\\anaconda3\\condabin;C:\\Program Files (x86)\\Common Files\\Oracle\\Java\\javapath;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Users\\coque\\anaconda3;C:\\Users\\coque\\anaconda3\\Scripts;C:\\Program;C:\\Program Files\\Git\\cmd;C:\\PATH_programs\\ffmpeg-4.4-full_build\\bin;C:\\Program Files\\nodejs\\;C:\\Users\\coque\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Program Files\\Graphviz\\bin;C:\\Users\\coque\\AppData\\Local\\GitHubDesktop\\bin;C:\\Users\\coque\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Users\\coque\\AppData\\Roaming\\npm;C:\\Users\\coque\\anaconda3\\condabin;C:\\Program Files (x86)\\Common Files\\Oracle\\Java\\javapath;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Users\\coque\\anaconda3;
# ...

# %%
p1 = subprocess.run('truffle test --show-events-on-failed-tests',capture_output=True, shell=True) #text=True)

print(p1.returncode)
print(p1.stdout.decode())
# Out:
# 1
# Using network 'development'.
#
#
# Compiling your contracts...
# ...
# > Compiling @chainlink\contracts\src\v0.8\interfaces\AggregatorV3Interface.sol
# > Compiling .\contracts\ArtCollectibles.sol
# > Compiling .\contracts\ClubOptions.sol
# > Compiling .\contracts\Genesis.sol
# > Compiling .\contracts\MainExp.sol
# > Compiling .\contracts\Migrations.sol
# > Compiling .\contracts\OEToken.sol
# > Compiling .\contracts\Services.sol
# > Compiling .\contracts\Treasury.sol
# > Compiling .\contracts\interfaces\IGenesis.sol
# > Compiling .\contracts\interfaces\IOEToken.sol
# > Compiling .\contracts\interfaces\standard\IERC165.sol
# > Compiling .\contracts\interfaces\standard\IERC20.sol
# > Compiling .\contracts\interfaces\standard\IERC2981.sol
# > Compiling .\contracts\interfaces\standard\IERC721.sol
# > Compiling .\contracts\interfaces\standard\IERC721Enumerable.sol
# > Compiling .\contracts\interfaces\standard\IERC721Metadata.sol
# ...

# %%
print(p1.stdout.decode())
# Out:
# Using network 'development'.
#
#
# Compiling your contracts...
# ...
# > Compiling @chainlink\contracts\src\v0.8\interfaces\AggregatorV3Interface.sol
# > Compiling .\contracts\ArtCollectibles.sol
# > Compiling .\contracts\ClubOptions.sol
# > Compiling .\contracts\Genesis.sol
# > Compiling .\contracts\MainExp.sol
# > Compiling .\contracts\Migrations.sol
# > Compiling .\contracts\OEToken.sol
# > Compiling .\contracts\Services.sol
# > Compiling .\contracts\Treasury.sol
# > Compiling .\contracts\interfaces\IGenesis.sol
# > Compiling .\contracts\interfaces\IOEToken.sol
# > Compiling .\contracts\interfaces\standard\IERC165.sol
# > Compiling .\contracts\interfaces\standard\IERC20.sol
# > Compiling .\contracts\interfaces\standard\IERC2981.sol
# > Compiling .\contracts\interfaces\standard\IERC721.sol
# > Compiling .\contracts\interfaces\standard\IERC721Enumerable.sol
# > Compiling .\contracts\interfaces\standard\IERC721Metadata.sol
# > Compiling .\contracts\interfaces\standard\IERC721Receiver.sol
# ...

# %%
p1.stderr.decode()
# Out:
# '\r\n> Duplicate contract names found for Services.\r\n> This can cause errors and unknown behavior. Please rename one of your contracts.\n'

# %%
p1 = subprocess.run('truffle test --show-events-on-failed-tests',capture_output=True, shell=True, text=True)
print(p1.stderr)
# Out:
# > Duplicate contract names found for Services.
# > This can cause errors and unknown behavior. Please rename one of your contracts.

# %%
print(p1.stdout)
# Out:
# Using network 'development'.
#
#
# Compiling your contracts...
# ...
# > Compiling @chainlink\contracts\src\v0.8\interfaces\AggregatorV3Interface.sol
# > Compiling .\contracts\ArtCollectibles.sol
# > Compiling .\contracts\ClubOptions.sol
# > Compiling .\contracts\Genesis.sol
# > Compiling .\contracts\MainExp.sol
# > Compiling .\contracts\Migrations.sol
# > Compiling .\contracts\OEToken.sol
# > Compiling .\contracts\Services134.sol
# > Compiling .\contracts\Treasury.sol
# > Compiling .\contracts\interfaces\IGenesis.sol
# > Compiling .\contracts\interfaces\IOEToken.sol
# > Compiling .\contracts\interfaces\standard\IERC165.sol
# > Compiling .\contracts\interfaces\standard\IERC20.sol
# > Compiling .\contracts\interfaces\standard\IERC2981.sol
# > Compiling .\contracts\interfaces\standard\IERC721.sol
# > Compiling .\contracts\interfaces\standard\IERC721Enumerable.sol
# > Compiling .\contracts\interfaces\standard\IERC721Metadata.sol
# ...

# %%
import itertools

# lista = [0,1,2]

# for x in itertools.dropwhile(lambda x: x==0,lista):
#     print(x)

for x in itertools.dropwhile(lambda x: re.search(" \d\) failing ", x),p1.stdout.split() ):
    print(x)
# Out:
# Using
# network
# 'development'.
# Compiling
# your
# contracts...
# ...
# >
# Compiling
# @chainlink\contracts\src\v0.8\interfaces\AggregatorV3Interface.sol
# >
# Compiling
# .\contracts\ArtCollectibles.sol
# >
# Compiling
# .\contracts\ClubOptions.sol
# >
# Compiling
# .\contracts\Genesis.sol
# >
# Compiling
# .\contracts\MainExp.sol
# >
# Compiling
# .\contracts\Migrations.sol
# >
# Compiling
# .\contracts\OEToken.sol
# >
# Compiling
# .\contracts\Services134.sol
# >
# Compiling
# .\contracts\Treasury.sol
# >
# Compiling
# .\contracts\interfaces\IGenesis.sol
# >
# Compiling
# .\contracts\interfaces\IOEToken.sol
# >
# Compiling
# .\contracts\interfaces\standard\IERC165.sol
# >
# Compiling
# .\contracts\interfaces\standard\IERC20.sol
# >
# Compiling
# .\contracts\interfaces\standard\IERC2981.sol
# >
# Compiling
# .\contracts\interfaces\standard\IERC721.sol
# >
# Compiling
# .\contracts\interfaces\standard\IERC721Enumerable.sol
# >
# Compiling
# ...

# %%
[line for line in p1.stdout.split() if re.search("1\)", line)]
# Out:
# ['1)', '1)']
